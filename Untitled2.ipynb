# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %%
file_path = r"C:\Users\thinkpad\Downloads\HW 4A Dataset Sp 2025.xlsx"  
df = pd.read_excel(file_path)

# %%
# Define the dependent variable (Flood Probability) and independent variables
y = df["FloodProbability"]  # Replace with the correct column name
X = df.drop(columns=["FloodProbability"])  # Remove the dependent variable

# Add a constant for regression (Intercept term)
X = sm.add_constant(X)

# Perform Backward Elimination
def backward_elimination(X, y, significance_level=0.10):
    variables = list(X.columns)
    while len(variables) > 0:
        X_selected = X[variables]
        model = sm.OLS(y, X_selected).fit()
        p_values = model.pvalues[1:]  # Exclude intercept
        max_p_value = p_values.max()
        
        if max_p_value > significance_level:
            excluded_var = p_values.idxmax()
            variables.remove(excluded_var)
        else:
            break
            
    return sm.OLS(y, X[variables]).fit()

# Run the stepwise regression (Backward Elimination)
final_model = backward_elimination(X, y)

# Print summary of the final model
print(final_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       FloodProbability   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.545e+04
# Date:                Thu, 13 Feb 2025   Prob (F-statistic):          1.19e-297
# Time:                        13:06:43   Log-Likelihood:                 1093.4
# No. Observations:                 200   AIC:                            -2145.
# Df Residuals:                     179   BIC:                            -2076.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt  # Make sure to import matplotlib.pyplot

# Define the dependent variable (Flood Probability) and independent variables
y = df["FloodProbability"]  # Replace with the correct column name
X = df.drop(columns=["FloodProbability"])  # Remove the dependent variable

# Visualize the correlation between features
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# Add a constant for regression (Intercept term)
X = sm.add_constant(X)

# Perform Backward Elimination
def backward_elimination(X, y, significance_level=0.10):
    variables = list(X.columns)
    while len(variables) > 0:
        X_selected = X[variables]
        model = sm.OLS(y, X_selected).fit()
        p_values = model.pvalues[1:]  # Exclude intercept
        max_p_value = p_values.max()
        
        if max_p_value > significance_level:
            excluded_var = p_values.idxmax()
            variables.remove(excluded_var)
        else:
            break
            
    return sm.OLS(y, X[variables]).fit()

# Run the stepwise regression (Backward Elimination)
final_model = backward_elimination(X, y)

# Print summary of the final model
print(final_model.summary())

# Visualize the residuals of the final model
residuals = final_model.resid
plt.figure(figsize=(10, 6))
sns.histplot(residuals, kde=True, color='blue', bins=20)
plt.title('Distribution of Residuals')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.show()

# Plot the residuals vs fitted values to check for homoscedasticity
fitted_values = final_model.fittedvalues
plt.figure(figsize=(10, 6))
sns.scatterplot(x=fitted_values, y=residuals)
plt.axhline(y=0, color='r', linestyle='--')
plt.title('Residuals vs Fitted Values')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.show()

# Visualize the distribution of the dependent variable (Flood Probability)
plt.figure(figsize=(10, 6))
sns.histplot(y, kde=True, color='green', bins=20)
plt.title('Distribution of Flood Probability')
plt.xlabel('Flood Probability')
plt.ylabel('Frequency')
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       FloodProbability   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.545e+04
# Date:                Thu, 13 Feb 2025   Prob (F-statistic):          1.19e-297
# Time:                        13:07:01   Log-Likelihood:                 1093.4
# No. Observations:                 200   AIC:                            -2145.
# Df Residuals:                     179   BIC:                            -2076.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...
